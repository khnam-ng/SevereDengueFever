# %%
"""
author: Vetivert? 💐 
created: 14/04/2025 @ 15:26:37
"""

import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
import pandas as pd # type: ignore
import seaborn as sns # type: ignore

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold # type: ignore
from sklearn.preprocessing import StandardScaler, label_binarize # type: ignore
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc # type: ignore
from sklearn.ensemble import RandomForestClassifier # type: ignore

import sys
import os

current_dir = os.path.abspath('')

parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

from src.utils.prefix_path import *
from src.utils.functions import *

# %%
# Load dataset
df = pd.read_csv(FULL_DATA_PATH, sep=";", header=3) #separator is ;
# df = df.apply(pd.to_numeric, errors='coerce')

# Drop redundant cols + rows
df.drop(REDUNDANT_ROWS, inplace=True)
df.index = range(len(df)) #reset index
df.drop(REDUNDANT_COLS, axis=1, inplace=True)

df.fillna(FILLNA_VALUES) #df[1] = df[1].fillna(0)
df['Other'] = pd.to_numeric(df['Other'], errors='coerce').fillna(1) #addtional diseases
df.iloc[np.where(df == '8(nặng xin về)')] = 8

for i in HEART_INDEX:
    df[i] = pd.to_numeric(df[i], errors='coerce')
    print(f"{i}: {df[str(i)].mean()}")
print("\nDiastolic BP < 80: Huyết áp tối ưu \nSystolic BP <= 130: Huyết áp bình thường, 130<x<140: Tiền tăng huyết áp")

# df.drop(HEART_INDEX, axis=1, inplace=True)

uniques, counts = np.unique(df['Diagnosis'], return_counts=True)
print('\nDiagnosis\'s classes: ',dict(zip(uniques, np.round(counts * 100 / len(df['Diagnosis']), 2))))
df['Diagnosis'] = np.where(df['Diagnosis'] == '3', '2', df['Diagnosis'])
df['Day of illness'] = np.where(df['Day of illness'] == '55', '5', df['Day of illness'])
df['Systolic BP'] = np.where(df['Systolic BP'] == 1120, 120, df['Systolic BP'])


# hematoma group
hema = df[HEMATOMA_COLS]
hema = hema.assign(stacked=hema.astype(str).agg(''.join, axis=1))
hema
hema['stacked'] = (pd.to_numeric(hema['stacked'], errors='coerce'))
hema['stacked_int'] = np.where(hema['stacked'] == 0, 0, 1)

df.insert(df.columns.get_loc(HEMATOMA_COLS[0]), 'hematoma', hema['stacked_int']) #get col index by its name
df.drop(HEMATOMA_COLS, axis=1, inplace=True)

# bleeding group
bleed = df[BLEEDING_COLS]
bleed = bleed.assign(stacked=bleed.astype(str).agg(''.join, axis=1))
bleed['stacked'] = (pd.to_numeric(bleed['stacked'], errors='coerce'))
bleed['stacked_int'] = np.where(bleed['stacked'] == 0, 0, 1)

df.insert(df.columns.get_loc(BLEEDING_COLS[0]), 'Mucosa membrane bleeding', bleed['stacked_int'])
df.drop(BLEEDING_COLS, axis=1, inplace=True)

# additional diseases group
add_diseases = df[ADDITIONAL_DISEASES]
add_diseases = add_diseases.assign(stacked=add_diseases.astype(str).agg(''.join, axis=1))
add_diseases['stacked'] = (pd.to_numeric(add_diseases['stacked'], errors='coerce'))
add_diseases['stacked_int'] = np.where(add_diseases['stacked'] == 0, 0, 1)

df.insert(df.columns.get_loc(ADDITIONAL_DISEASES[0]), 'additional_diseases', add_diseases['stacked_int'])
df.drop(ADDITIONAL_DISEASES, axis=1, inplace=True)
# Out:
# Pulse rate: 89.60148514851485
# Systolic BP: 117.25
# Diastolic BP: 70.63861386138613
#
# Diastolic BP < 80: Huyết áp tối ưu
# Systolic BP <= 130: Huyết áp bình thường, 130<x<140: Tiền tăng huyết áp
#
# Diagnosis's classes:  {'1': 56.4, '2': 39.66, '3': 3.94}

# %%
df.loc[:, :'Oliguria'].isnull().sum() #check missing values
# Out:
# Diagnosis                       0
# Gende                           0
# DHF infection His.              4
# additional_diseases             0
# Fever                           2
# Bleeding                        2
# Fatigue                         2
# Day of illness                  3
# Level of temp                 184
# Duration fever                192
# Headache                        2
# Body ache                       2
# Rash                            2
# hematoma                        0
# Mucosa membrane bleeding        0
# Pleural effusion                2
# Ascites                         2
# Pericardial effusion            2
# Vomiting                        3
# Abdominal pain or tendness      3
# Liver enlargement               3
# Oliguria                        5
# dtype: int64

# %% [markdown]
# ## STRATEGY 1: should we keep MISSING_2017 based on 2019 dataset

# %%
# strategy 1, 20% test_set = 0.2 * range(line 0, line 221) + 0.2 * range(line 222, line 407)
df_set = df.loc[222:, :'Oliguria'].copy().fillna(0)

x1_train, x1_test, y1_train, y1_test = train_test_split(df_set.drop(columns=['Diagnosis']), df_set['Diagnosis'], \
                                                    test_size=0.2, random_state=None, stratify=df_set['Diagnosis'])
print('x1_train shape: ', x1_train.shape, 'y1_train shape: ',  y1_train.shape)
print('x1_test shape: ', x1_test.shape, 'y1_test shape: ',  y1_test.shape)
uniques, counts = np.unique(y1_test, return_counts=True)
print('percentage of classes: ',dict(zip(uniques, np.round(counts * 100 / len(y1_test), 2))))

rf_1 = RandomForestClassifier(n_estimators=100, random_state=None)
rf_1.fit(x1_train, y1_train)

y1_pred = rf_1.predict(x1_test)
accuracy = accuracy_score(y1_test, y1_pred)
print(f"Accuracy: {accuracy:.2f}")
# print(classification_report(y1_test, y1_pred))

uniques, counts = np.unique(y1_pred, return_counts=True)
print('percentage of predictions: ',dict(zip(uniques, np.round(counts * 100 / len(y1_pred), 2))))

# Plotting feature importances
importances = rf_1.feature_importances_
indices = np.argsort(importances)[::-1]
features = x1_train.columns
plt.figure(figsize=(12, 8))
plt.title("Feature importances")
plt.bar(range(x1_train.shape[1]), importances[indices], align="center")
plt.xticks(range(x1_train.shape[1]), features[indices], rotation=90)
plt.xlim([-1, x1_train.shape[1]])
plt.axhline(y=importances.mean(), color='r', linestyle='--')
plt.show()
# Out:
# x1_train shape:  (147, 24) y1_train shape:  (147,)
# x1_test shape:  (37, 24) y1_test shape:  (37,)
# percentage of classes:  {'1': 45.95, '2': 54.05}
# Accuracy: 0.68
# percentage of predictions:  {'1': 56.76, '2': 43.24}

# %%
# Get split values for each feature
split_values = extract_split_values(rf_1, features)


# Sort features by importance
importances = rf_1.feature_importances_
sorted_idx = np.argsort(importances)[::-1]
top_features = [features[i] for i in sorted_idx[:9]]  # Top 5 features

plt.figure(figsize=(12, 8))
for i, feature in enumerate(top_features):
    plt.subplot(3, 3, i+1)
    # plt.hist(split_values[feature], bins=20)
    sns.histplot(split_values[feature], kde=True)
    plt.title(f"{feature} Split Values")
    plt.xlabel("Threshold")
    plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## strategy 2, with HEART_INDEX

# %%
# df.drop(HEART_INDEX, axis=1, inplace=True)

# %%
df_set2 = df.loc[:, :'Oliguria'].copy()
for col in MISSING_2017:
    df_set2[col] = pd.to_numeric(df_set2[col], errors='coerce')
    df_set2.fillna(df_set2[col].mean(), inplace=True)
df_set2.fillna(0, inplace=True)

x2_train, x2_test, y2_train, y2_test = train_test_split(df_set2.drop(columns=['Diagnosis']), df_set2['Diagnosis'], \
                                                    test_size=0.2, random_state=15, stratify=df_set2['Diagnosis'])
print('x2_train shape: ', x2_train.shape, 'y2_train shape: ',  y2_train.shape)
print('x2_test shape: ', x2_test.shape, 'y2_test shape: ',  y2_test.shape)
uniques, counts = np.unique(y2_test, return_counts=True)
print('percentage of classes: ',dict(zip(uniques, np.round(counts * 100 / len(y2_test), 2))))
# Out:
# x2_train shape:  (324, 24) y2_train shape:  (324,)
# x2_test shape:  (82, 24) y2_test shape:  (82,)
# percentage of classes:  {'1': 56.1, '2': 43.9}

# %%
rf_2 = RandomForestClassifier(n_estimators=100, random_state=16)
rf_2.fit(x2_train, y2_train)

y2_pred = rf_2.predict(x2_test)
accuracy = accuracy_score(y2_test, y2_pred)
print(f"Accuracy: {accuracy:.2f}")
# print(classification_report(y2_test, y2_pred))

uniques, counts = np.unique(y2_pred, return_counts=True)
print('percentage of predictions: ',dict(zip(uniques, np.round(counts * 100 / len(y2_pred), 2))))

# Plotting feature importances
importances = rf_2.feature_importances_
indices = np.argsort(importances)[::-1]
features = x2_train.columns
plt.figure(figsize=(12, 8))
plt.title("Feature importances")
plt.bar(range(x2_train.shape[1]), importances[indices], align="center")
plt.xticks(range(x2_train.shape[1]), features[indices], rotation=90)
plt.xlim([-1, x2_train.shape[1]])
plt.axhline(y=importances.mean(), color='r', linestyle='--')
plt.show()
# Out:
# Accuracy: 0.68
# percentage of predictions:  {'1': 60.98, '2': 39.02}

# %%
# Get split values for each feature
split_values = extract_split_values(rf_2, features)


# Sort features by importance
importances = rf_2.feature_importances_
sorted_idx = np.argsort(importances)[::-1]
top_features = [features[i] for i in sorted_idx[:9]]  # Top 5 features

plt.figure(figsize=(12, 8))
for i, feature in enumerate(top_features):
    plt.subplot(3, 3, i+1)
    # plt.hist(split_values[feature], bins=20)
    sns.histplot(split_values[feature], kde=True)
    plt.title(f"{feature} Split Values")
    plt.xlabel("Threshold")
    plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform
from sklearn.metrics import make_scorer, roc_auc_score


# Define parameter distributions
param_distributions = {
    'n_estimators': randint(50, 500),
    'max_depth': randint(5, 50),
    'min_samples_split': randint(2, 15),
    'min_samples_leaf': randint(1, 10),
    'max_features': ['sqrt', 'log2', None]
}
scorer = make_scorer(roc_auc_score)

# Setup RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=RandomForestClassifier(random_state=16),
    param_distributions=param_distributions,
    n_iter=100,  # number of parameter settings sampled
    cv=5,
    scoring=scorer,
    n_jobs=-1,
    verbose=2,
    random_state=16
)

# Fit the random search
random_search.fit(x2_train, y2_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=46, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=173; total time=   0.4s
# [CV] END max_depth=46, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=173; total time=   0.4s
# [CV] END max_depth=46, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=173; total time=   0.4s
# [CV] END max_depth=46, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=173; total time=   0.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=210; total time=   0.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=210; total time=   0.5s
# [CV] END max_depth=46, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=173; total time=   0.5s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=210; total time=   0.5s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=210; total time=   0.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=210; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=256; total time=   0.5s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=11, n_estimators=450; total time=   0.9s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=11, n_estimators=450; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=256; total time=   0.5s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=11, n_estimators=450; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=256; total time=   0.7s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=11, n_estimators=450; total time=   1.0s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=11, n_estimators=450; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=256; total time=   0.6s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=256; total time=   0.6s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=215; total time=   0.5s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=215; total time=   0.5s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=215; total time=   0.5s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=215; total time=   0.5s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=334; total time=   0.8s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=334; total time=   0.7s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=334; total time=   0.7s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=334; total time=   0.8s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=215; total time=   0.6s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=334; total time=   0.9s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=230; total time=   0.5s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=230; total time=   0.5s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=230; total time=   0.5s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=230; total time=   0.5s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=230; total time=   0.6s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=235; total time=   0.5s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=235; total time=   0.5s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=157; total time=   0.4s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=322; total time=   0.7s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=322; total time=   0.7s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=235; total time=   0.6s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=235; total time=   0.5s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=322; total time=   0.7s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=235; total time=   0.6s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=322; total time=   0.8s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=322; total time=   0.8s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=493; total time=   1.1s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=493; total time=   1.1s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=493; total time=   1.1s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=157; total time=   0.4s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=157; total time=   0.4s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=157; total time=   0.3s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=493; total time=   1.1s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=493; total time=   1.1s
# [CV] END max_depth=27, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=54; total time=   0.1s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=157; total time=   0.5s
# [CV] END max_depth=27, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=54; total time=   0.2s
# [CV] END max_depth=27, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=54; total time=   0.2s
# [CV] END max_depth=27, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=54; total time=   0.2s
# [CV] END max_depth=27, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=54; total time=   0.1s
# [CV] END max_depth=46, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=318; total time=   0.7s
# [CV] END max_depth=46, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=318; total time=   0.7s
# [CV] END max_depth=46, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=318; total time=   0.7s
# [CV] END max_depth=46, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=318; total time=   0.7s
# [CV] END max_depth=46, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=318; total time=   0.7s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=293; total time=   0.6s
# [CV] END max_depth=43, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=136; total time=   0.3s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=293; total time=   0.6s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=293; total time=   0.7s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=293; total time=   0.7s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=293; total time=   0.7s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=499; total time=   1.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=499; total time=   1.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=499; total time=   1.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=499; total time=   1.2s
# [CV] END max_depth=43, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=136; total time=   0.3s
# [CV] END max_depth=43, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=136; total time=   0.3s
# [CV] END max_depth=43, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=136; total time=   0.3s
# [CV] END max_depth=43, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=136; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=181; total time=   0.4s
# [CV] END max_depth=47, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=403; total time=   1.0s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=499; total time=   1.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=181; total time=   0.4s
# [CV] END max_depth=47, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=403; total time=   0.9s
# [CV] END max_depth=47, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=403; total time=   1.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=181; total time=   0.5s
# [CV] END max_depth=47, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=403; total time=   1.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=181; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=181; total time=   0.5s
# [CV] END max_depth=47, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=403; total time=   1.0s
# [CV] END max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=115; total time=   0.2s
# [CV] END max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=115; total time=   0.3s
# [CV] END max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=115; total time=   0.3s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=193; total time=   0.4s[CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=193; total time=   0.4s
#
# [CV] END max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=115; total time=   0.3s
# [CV] END max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=115; total time=   0.3s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=193; total time=   0.5s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=193; total time=   0.4s
# [CV] END max_depth=35, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=193; total time=   0.5s
# [CV] END max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=390; total time=   0.9s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=166; total time=   0.4s
# [CV] END max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=390; total time=   0.9s
# [CV] END max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=390; total time=   0.9s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=166; total time=   0.4s
# [CV] END max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=390; total time=   0.9s
# [CV] END max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=390; total time=   1.0s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=166; total time=   0.4s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=166; total time=   0.4s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=113; total time=   0.3s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=113; total time=   0.3s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=166; total time=   0.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=113; total time=   0.3s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=113; total time=   0.3s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=113; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=248; total time=   0.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=248; total time=   0.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=248; total time=   0.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=248; total time=   0.6s
# [CV] END max_depth=39, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=73; total time=   0.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=248; total time=   0.7s
# [CV] END max_depth=39, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=73; total time=   0.2s
# [CV] END max_depth=39, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=73; total time=   0.2s
# [CV] END max_depth=39, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=73; total time=   0.2s
# [CV] END max_depth=39, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=73; total time=   0.2s
# [CV] END max_depth=48, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=457; total time=   1.1s
# [CV] END max_depth=48, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=457; total time=   1.1s
# [CV] END max_depth=48, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=457; total time=   1.0s
# [CV] END max_depth=48, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=457; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=116; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=116; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=116; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=116; total time=   0.3s
# [CV] END max_depth=48, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=457; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=116; total time=   0.3s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=469; total time=   1.0s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=469; total time=   1.1s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=469; total time=   1.1s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=469; total time=   1.1s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=469; total time=   1.1s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=308; total time=   0.7s
# [CV] END max_depth=44, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=452; total time=   1.0s
# [CV] END max_depth=44, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=452; total time=   1.0s
# [CV] END max_depth=44, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=452; total time=   1.1s
# [CV] END max_depth=44, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=452; total time=   1.1s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=471; total time=   1.0s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=471; total time=   1.0s
# [CV] END max_depth=44, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=452; total time=   1.1s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=471; total time=   1.1s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=308; total time=   0.7s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=471; total time=   1.2s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=308; total time=   0.7s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=471; total time=   1.2s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=308; total time=   0.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=308; total time=   0.8s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=319; total time=   0.8s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=56; total time=   0.1s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=56; total time=   0.1s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=198; total time=   0.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=198; total time=   0.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=198; total time=   0.5s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=56; total time=   0.1s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=198; total time=   0.5s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=56; total time=   0.1s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=198; total time=   0.5s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=319; total time=   0.8s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=319; total time=   0.8s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=56; total time=   0.1s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=319; total time=   0.8s
# [CV] END max_depth=29, max_features=sqrt, min_samples_leaf=9, min_samples_split=13, n_estimators=84; total time=   0.2s
# [CV] END max_depth=29, max_features=sqrt, min_samples_leaf=9, min_samples_split=13, n_estimators=84; total time=   0.2s
# [CV] END max_depth=29, max_features=sqrt, min_samples_leaf=9, min_samples_split=13, n_estimators=84; total time=   0.2s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=319; total time=   0.9s
# [CV] END max_depth=29, max_features=sqrt, min_samples_leaf=9, min_samples_split=13, n_estimators=84; total time=   0.2s
# [CV] END max_depth=29, max_features=sqrt, min_samples_leaf=9, min_samples_split=13, n_estimators=84; total time=   0.2s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=167; total time=   0.4s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=167; total time=   0.4s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=167; total time=   0.4s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=167; total time=   0.4s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=167; total time=   0.4s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=431; total time=   0.9s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=431; total time=   1.0s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=431; total time=   1.0s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=431; total time=   1.1s
# [CV] END max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=431; total time=   1.2s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=4, min_samples_split=11, n_estimators=312; total time=   0.7s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=4, min_samples_split=11, n_estimators=312; total time=   0.7s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=4, min_samples_split=11, n_estimators=312; total time=   0.8s
# [CV] END max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=232; total time=   0.6s
# [CV] END max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=232; total time=   0.5s
# [CV] END max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=232; total time=   0.5s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=4, min_samples_split=11, n_estimators=312; total time=   0.7s[CV] END max_depth=44, max_features=log2, min_samples_leaf=4, min_samples_split=11, n_estimators=312; total time=   0.7s
#
# [CV] END max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=232; total time=   0.6s
# [CV] END max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=232; total time=   0.6s
# [CV] END max_depth=33, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=92; total time=   0.2s
# [CV] END max_depth=33, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=92; total time=   0.3s
# [CV] END max_depth=33, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=92; total time=   0.2s
# [CV] END max_depth=33, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=92; total time=   0.2s
# [CV] END max_depth=33, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=92; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=122; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=122; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=122; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=122; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=122; total time=   0.3s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=86; total time=   0.2s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=445; total time=   1.0s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=445; total time=   1.0s
# [CV] END max_depth=38, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=233; total time=   0.5s
# [CV] END max_depth=38, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=233; total time=   0.5s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=445; total time=   1.0s
# [CV] END max_depth=38, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=233; total time=   0.5s
# [CV] END max_depth=38, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=233; total time=   0.6s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=445; total time=   1.1s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=86; total time=   0.2s
# [CV] END max_depth=38, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=233; total time=   0.6s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=86; total time=   0.2s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=86; total time=   0.2s
# [CV] END max_depth=14, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=86; total time=   0.2s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=445; total time=   1.1s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=437; total time=   1.0s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=285; total time=   0.6s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=437; total time=   1.0s[CV] END max_depth=18, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=437; total time=   0.9s
#
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=437; total time=   1.1s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=285; total time=   0.7s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=285; total time=   0.7s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=285; total time=   0.7s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=437; total time=   1.1s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=285; total time=   0.7s
# [CV] END max_depth=45, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=423; total time=   1.0s
# [CV] END max_depth=45, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=423; total time=   1.0s
# [CV] END max_depth=45, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=423; total time=   1.0s
# [CV] END max_depth=45, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=423; total time=   1.0s
# [CV] END max_depth=45, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=423; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=127; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=127; total time=   0.3s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=9, min_samples_split=3, n_estimators=418; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=127; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=127; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=304; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=304; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=304; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=127; total time=   0.3s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=9, min_samples_split=3, n_estimators=418; total time=   0.9s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=9, min_samples_split=3, n_estimators=418; total time=   0.9s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=9, min_samples_split=3, n_estimators=418; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=304; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=304; total time=   0.8s
# [CV] END max_depth=30, max_features=None, min_samples_leaf=9, min_samples_split=3, n_estimators=418; total time=   1.0s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=98; total time=   0.3s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=98; total time=   0.2s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=98; total time=   0.3s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=98; total time=   0.2s
# [CV] END max_depth=18, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=98; total time=   0.3s
# [CV] END max_depth=22, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=108; total time=   0.3s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=496; total time=   1.1s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=496; total time=   1.3s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=496; total time=   1.3s
# [CV] END max_depth=22, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=108; total time=   0.3s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=461; total time=   1.1s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=461; total time=   1.1s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=496; total time=   1.2s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=461; total time=   1.1s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=496; total time=   1.2s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=461; total time=   1.2s
# [CV] END max_depth=18, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=461; total time=   1.2s
# [CV] END max_depth=22, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=108; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=484; total time=   1.1s
# [CV] END max_depth=22, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=108; total time=   0.3s
# [CV] END max_depth=22, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=108; total time=   0.3s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=484; total time=   1.1s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=484; total time=   1.1s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=484; total time=   1.1s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=484; total time=   1.1s
# [CV] END max_depth=23, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=151; total time=   0.4s
# [CV] END max_depth=23, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=151; total time=   0.4s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=8, min_samples_split=10, n_estimators=244; total time=   0.6s
# [CV] END max_depth=23, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=151; total time=   0.3s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=8, min_samples_split=10, n_estimators=244; total time=   0.6s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=8, min_samples_split=10, n_estimators=244; total time=   0.6s
# [CV] END max_depth=23, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=151; total time=   0.4s
# [CV] END max_depth=23, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=151; total time=   0.4s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=8, min_samples_split=10, n_estimators=244; total time=   0.7s
# [CV] END max_depth=49, max_features=None, min_samples_leaf=8, min_samples_split=10, n_estimators=244; total time=   0.6s
# [CV] END max_depth=48, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=369; total time=   0.9s
# [CV] END max_depth=48, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=369; total time=   0.9s
# [CV] END max_depth=48, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=369; total time=   0.9s
# [CV] END max_depth=48, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=369; total time=   0.9s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=232; total time=   0.5s
# [CV] END max_depth=48, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=369; total time=   1.0s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=232; total time=   0.5s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=232; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=213; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=213; total time=   0.5s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=232; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=213; total time=   0.5s
# [CV] END max_depth=16, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=232; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=213; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=213; total time=   0.6s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=308; total time=   0.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=308; total time=   0.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=308; total time=   0.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=308; total time=   0.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=308; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=311; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=311; total time=   0.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=311; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=311; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=233; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=311; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=233; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=233; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=233; total time=   0.5s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=8, min_samples_split=9, n_estimators=398; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=233; total time=   0.5s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=8, min_samples_split=9, n_estimators=398; total time=   1.0s
# [CV] END max_depth=43, max_features=None, min_samples_leaf=3, min_samples_split=4, n_estimators=234; total time=   0.6s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=8, min_samples_split=9, n_estimators=398; total time=   1.0s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=8, min_samples_split=9, n_estimators=398; total time=   1.0s
# [CV] END max_depth=43, max_features=None, min_samples_leaf=3, min_samples_split=4, n_estimators=234; total time=   0.6s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=79; total time=   0.2s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=79; total time=   0.2s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=8, min_samples_split=9, n_estimators=398; total time=   1.1s
# [CV] END max_depth=43, max_features=None, min_samples_leaf=3, min_samples_split=4, n_estimators=234; total time=   0.6s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=79; total time=   0.2s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=79; total time=   0.2s
# [CV] END max_depth=43, max_features=None, min_samples_leaf=3, min_samples_split=4, n_estimators=234; total time=   0.6s
# [CV] END max_depth=43, max_features=None, min_samples_leaf=3, min_samples_split=4, n_estimators=234; total time=   0.6s
# [CV] END max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=79; total time=   0.2s
# [CV] END max_depth=37, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=391; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=227; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=227; total time=   0.6s
# [CV] END max_depth=37, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=391; total time=   1.0s
# [CV] END max_depth=37, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=391; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=227; total time=   0.6s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=227; total time=   0.6s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=6, min_samples_split=12, n_estimators=206; total time=   0.4s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=227; total time=   0.6s
# [CV] END max_depth=37, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=391; total time=   0.9s
# [CV] END max_depth=37, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=391; total time=   0.9s
# [CV] END max_depth=43, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=328; total time=   0.8s
# [CV] END max_depth=43, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=328; total time=   0.8s
# [CV] END max_depth=43, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=328; total time=   0.8s
# [CV] END max_depth=43, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=328; total time=   0.8s
# [CV] END max_depth=43, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=328; total time=   0.8s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=6, min_samples_split=12, n_estimators=206; total time=   0.5s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=140; total time=   0.3s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=6, min_samples_split=12, n_estimators=206; total time=   0.5s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=6, min_samples_split=12, n_estimators=206; total time=   0.5s
# [CV] END max_depth=13, max_features=log2, min_samples_leaf=6, min_samples_split=12, n_estimators=206; total time=   0.5s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=140; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=140; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=140; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=140; total time=   0.4s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=222; total time=   0.5s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=222; total time=   0.5s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=222; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=117; total time=   0.3s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=222; total time=   0.6s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=437; total time=   1.0s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=437; total time=   1.0s
# [CV] END max_depth=44, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=222; total time=   0.6s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=437; total time=   1.0s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=437; total time=   1.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=117; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=117; total time=   0.3s
# [CV] END max_depth=12, max_features=None, min_samples_leaf=7, min_samples_split=4, n_estimators=437; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=117; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=102; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=117; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=102; total time=   0.2s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=102; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=102; total time=   0.2s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=102; total time=   0.2s
# [CV] END max_depth=29, max_features=None, min_samples_leaf=9, min_samples_split=5, n_estimators=361; total time=   0.9s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=101; total time=   0.2s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=101; total time=   0.2s
# [CV] END max_depth=29, max_features=None, min_samples_leaf=9, min_samples_split=5, n_estimators=361; total time=   0.9s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=101; total time=   0.2s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=101; total time=   0.2s
# [CV] END max_depth=29, max_features=None, min_samples_leaf=9, min_samples_split=5, n_estimators=361; total time=   1.0s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=8, min_samples_split=4, n_estimators=101; total time=   0.3s
# [CV] END max_depth=29, max_features=None, min_samples_leaf=9, min_samples_split=5, n_estimators=361; total time=   0.9s
# [CV] END max_depth=29, max_features=None, min_samples_leaf=9, min_samples_split=5, n_estimators=361; total time=   1.0s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=299; total time=   0.7s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=299; total time=   0.7s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=299; total time=   0.7s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=299; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=264; total time=   0.6s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=299; total time=   0.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=399; total time=   0.8s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=264; total time=   0.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=399; total time=   0.9s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=264; total time=   0.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=399; total time=   1.0s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=264; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=264; total time=   0.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=399; total time=   1.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=10, n_estimators=399; total time=   1.0s
# [CV] END max_depth=17, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=278; total time=   0.6s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   1.2s
# [CV] END max_depth=17, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=278; total time=   0.6s
# [CV] END max_depth=17, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=278; total time=   0.7s
# [CV] END max_depth=17, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=278; total time=   0.7s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=6, min_samples_split=11, n_estimators=398; total time=   0.9s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=6, min_samples_split=11, n_estimators=398; total time=   0.9s
# [CV] END max_depth=17, max_features=None, min_samples_leaf=9, min_samples_split=6, n_estimators=278; total time=   0.7s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=310; total time=   0.8s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=6, min_samples_split=11, n_estimators=398; total time=   1.0s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=6, min_samples_split=11, n_estimators=398; total time=   1.0s
# [CV] END max_depth=16, max_features=None, min_samples_leaf=6, min_samples_split=11, n_estimators=398; total time=   1.0s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   1.1s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   1.2s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   1.3s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   1.2s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=310; total time=   0.7s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=310; total time=   0.8s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=310; total time=   0.8s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=325; total time=   0.7s
# [CV] END max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=310; total time=   0.8s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=325; total time=   0.7s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=325; total time=   0.8s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=325; total time=   0.8s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=325; total time=   0.8s
# [CV] END max_depth=25, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=353; total time=   0.8s
# [CV] END max_depth=25, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=353; total time=   0.9s
# [CV] END max_depth=25, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=353; total time=   0.8s
# [CV] END max_depth=25, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=353; total time=   0.9s
# [CV] END max_depth=25, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=353; total time=   0.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   0.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   0.9s
# [CV] END max_depth=31, max_features=log2, min_samples_leaf=6, min_samples_split=13, n_estimators=269; total time=   0.6s
# [CV] END max_depth=31, max_features=log2, min_samples_leaf=6, min_samples_split=13, n_estimators=269; total time=   0.6s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=206; total time=   0.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   0.9s
# [CV] END max_depth=31, max_features=log2, min_samples_leaf=6, min_samples_split=13, n_estimators=269; total time=   0.6s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=206; total time=   0.5s
# [CV] END max_depth=31, max_features=log2, min_samples_leaf=6, min_samples_split=13, n_estimators=269; total time=   0.7s
# [CV] END max_depth=31, max_features=log2, min_samples_leaf=6, min_samples_split=13, n_estimators=269; total time=   0.6s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=206; total time=   0.5s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=206; total time=   0.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   0.9s
# [CV] END max_depth=32, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=206; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=256; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=256; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=256; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=256; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=256; total time=   0.6s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=296; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=296; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=296; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=296; total time=   0.7s
# [CV] END max_depth=11, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=296; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=346; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=346; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=346; total time=   0.9s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=141; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=141; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=141; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=346; total time=   0.8s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=141; total time=   0.3s
# [CV] END max_depth=27, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=141; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=346; total time=   0.9s
# [CV] END max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=125; total time=   0.3s
# [CV] END max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=125; total time=   0.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2, n_estimators=380; total time=   0.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2, n_estimators=380; total time=   0.9s
# [CV] END max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=125; total time=   0.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2, n_estimators=380; total time=   1.0s
# [CV] END max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=125; total time=   0.3s
# [CV] END max_depth=39, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=125; total time=   0.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2, n_estimators=380; total time=   0.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2, n_estimators=380; total time=   0.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=188; total time=   0.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=188; total time=   0.4s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=188; total time=   0.5s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=188; total time=   0.5s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=188; total time=   0.5s
# [CV] END max_depth=34, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=213; total time=   0.5s
# [CV] END max_depth=34, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=213; total time=   0.5s
# [CV] END max_depth=34, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=213; total time=   0.6s
# [CV] END max_depth=34, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=213; total time=   0.6s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=203; total time=   0.4s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=203; total time=   0.4s
# [CV] END max_depth=34, max_features=None, min_samples_leaf=1, min_samples_split=13, n_estimators=213; total time=   0.5s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=203; total time=   0.4s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=203; total time=   0.5s
# [CV] END max_depth=34, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=203; total time=   0.5s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=445; total time=   0.9s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=445; total time=   1.0s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=445; total time=   1.0s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=445; total time=   1.0s
# [CV] END max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=445; total time=   1.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=380; total time=   0.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=380; total time=   0.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=380; total time=   0.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=380; total time=   0.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=380; total time=   0.6s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=16),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7eba9cab32b0>,
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7eba2f8a9420>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7eba328b2f20>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7eba328b0850>},
#                    random_state=16,
#                    scoring=make_scorer(roc_auc_score, response_method='predict'),
#                    verbose=2)

# %%
rf_cv = RandomForestClassifier(max_depth=17, max_features='log2', min_samples_leaf=2,
                       min_samples_split=7, n_estimators=115, random_state=16)
rf_cv.fit(x2_train, y2_train)

y_pred = rf_cv.predict(x2_test)
accuracy = accuracy_score(y2_test, y2_pred)
print(f"Accuracy: {accuracy:.2f}")
# print(classification_report(y2_test, y2_pred))

uniques, counts = np.unique(y2_pred, return_counts=True)
print('percentage of predictions: ',dict(zip(uniques, np.round(counts * 100 / len(y2_pred), 2))))

# Plotting feature importances
importances = rf_cv.feature_importances_
indices = np.argsort(importances)[::-1]
features = x2_train.columns
plt.figure(figsize=(12, 8))
plt.title("Feature importances")
plt.bar(range(x2_train.shape[1]), importances[indices], align="center")
plt.xticks(range(x2_train.shape[1]), features[indices], rotation=90)
plt.xlim([-1, x2_train.shape[1]])
plt.axhline(y=importances.mean(), color='r', linestyle='--')
plt.show()
# Out:
# Accuracy: 0.73
# percentage of predictions:  {'1': 56.76, '2': 43.24}

# %%
# Get split values for each feature
features = x2_train.columns
split_values = extract_split_values(rf_cv, features)


# Sort features by importance
importances = rf_cv.feature_importances_
sorted_idx = np.argsort(importances)[::-1]
top_features = [features[i] for i in sorted_idx[:9]]  # Top 5 features

plt.figure(figsize=(12, 8))
for i, feature in enumerate(top_features):
    plt.subplot(3, 3, i+1)
    # plt.hist(split_values[feature], bins=20)
    sns.histplot(split_values[feature], kde=True)
    plt.title(f"{feature} Split Values")
    plt.xlabel("Threshold")
    plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
import shap

explainer = shap.TreeExplainer(rf_cv)

shap_values = explainer(x2_test)

m = np.abs(shap_values.values).mean(0).round(2)
# for i in range(m.shape[0]):
#     if m[i][0] >= 0.01:
#         print(f"{features[i]}: {m[i][0]}")

# shap.summary_plot(shap_values, x2_test)
# Create a bar plot of feature importance
plt.figure(figsize=(12, 8))
important_features = []
important_values = []

for i in range(m.shape[0]):
    if m[i][0] >= 0.01:
        important_features.append(features[i])
        important_values.append(m[i][0])

# Sort by importance
sorted_indices = np.argsort(important_values)
sorted_features = [important_features[i] for i in sorted_indices]
sorted_values = [important_values[i] for i in sorted_indices]

plt.barh(range(len(sorted_features)), sorted_values, align='center')
plt.yticks(range(len(sorted_features)), sorted_features)
plt.xlabel('Mean |SHAP Value|')
plt.ylabel('Features')
plt.title('Important Features (SHAP Value >= 0.01)')
plt.tight_layout()
plt.show()
# shap.force_plot(explainer.expected_value[1], shap_values[1][2], x2_test[2])

# %%
import xgboost as xgb
from xgboost import XGBClassifier
